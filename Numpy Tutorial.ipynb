# %% [markdown]
# # Numpy Tutorial

# %%
import numpy as np

# %%
myarr=np.array([[2,45,8,6]],np.int32)

# %%
myarr[0,1]
# Out:
# 45

# %%
myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int32')

# %%
myarr[0,1]=6

# %%
myarr
# Out:
# array([[2, 6, 8, 6]])

# %% [markdown]
# # Array Creation: Conversion from other python structure
